# %% [markdown]
# **Generar imagene CWT con Mexican Hat**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pywt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 23.1
# [notice] To update, run: C:\Users\hpalm\anaconda3\python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv(r"C:\Users\hpalm\Desktop\Programacion\Proyecto_de_grado\Codigo_matlab\NEW_paciente_P03.csv")
df
# Out:
#             channel1  channel2      channel3      channel4      channel5  \
# 0       4.891000e-06 -0.000010 -1.510600e-06  1.116400e-07  7.592200e-07
# 1       2.694300e-06 -0.000006 -6.714000e-07  1.230300e-06 -5.839700e-07
# 2       2.316400e-07 -0.000005 -5.220200e-22  2.064400e-06  8.703500e-08
# 3      -1.839400e-06 -0.000006  5.035500e-07  3.300900e-06  1.429400e-06
# 4      -1.183900e-06 -0.000007 -1.510600e-06  3.748100e-06  1.764700e-06
# ...              ...       ...           ...           ...           ...
# 359995  4.752300e-05  0.000004 -1.970600e-04 -3.258200e-05  5.110900e-06
# 359996  2.872300e-05 -0.000003 -1.777500e-04 -4.131000e-05 -1.267600e-06
# 359997 -7.196600e-06  0.000037 -1.591200e-04 -3.946400e-05 -4.456900e-06
# 359998 -2.733900e-05  0.000064 -1.482100e-04 -3.929600e-05 -6.639200e-06
# 359999 -2.364600e-05  0.000035 -1.456900e-04 -4.768900e-05 -1.117100e-05
#
#         channel6  channel7  channel8  channel9
# ...

# %%
data1=df.iloc[:,2]
data2=data1[120001:121500]
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(data2, color='tab:blue')
plt.show()

# %%
# variables para iterar la segmentacion superpuesta
i = 0
j = 0
h = 0
k = 300

# %%
#ciclo para generar las images para todas los canales y posturas
# Clase 1

i = 0
j= 0

for k in range(300,6001,150):  
  while(j<8):

        data1=df.iloc[:,j]
        data2=data1[i:k]  
        cwtmatr, freqs = pywt.cwt(data2, np.arange(1,100,1), 'mexh')
        plt.imshow(cwtmatr, cmap='inferno', aspect='auto', extent=[0, 1.5, 100, 0])
        plt.gca().invert_yaxis()
        plt.axis('off')
        plt.savefig(rf'D:\TESIS\6000 datos\Datos\P10\Mexican_Hat_img\clase_1\{i}_{k}_{j}_mexh.png', bbox_inches='tight', pad_inches=0)
    
        j=j+1
  j = 0
  i=i+150

# %%
#ciclo para generar las images para todas los canales y posturas

# Clase 2

i = 6000
j= 0

for k in range(6300,12001,150):  
  while(j<8):

        data1=df.iloc[:,j]
        data2=data1[i:k]  
        cwtmatr, freqs = pywt.cwt(data2, np.arange(1,100,1), 'mexh')
        plt.imshow(cwtmatr, cmap='inferno', aspect='auto', extent=[0, 1.5, 100, 0])
        plt.gca().invert_yaxis()
        plt.axis('off')
        plt.savefig(rf'D:\TESIS\6000 datos\Datos\P10\Mexican_Hat_img\clase_2\{i}_{k}_{j}_mexh.png', bbox_inches='tight', pad_inches=0)
    
        j=j+1
  j = 0
  i=i+150

# %%
# Clase 3

i = 12000
j= 0

for k in range(12300,18001,150):  
  while(j<8):

        data1=df.iloc[:,j]
        data2=data1[i:k]  
        cwtmatr, freqs = pywt.cwt(data2, np.arange(1,100,1), 'mexh')
        plt.imshow(cwtmatr, cmap='inferno', aspect='auto', extent=[0, 1.5, 100, 0])
        plt.gca().invert_yaxis()
        plt.axis('off')
        plt.savefig(rf'D:\TESIS\6000 datos\Datos\P10\Mexican_Hat_img\clase_3\{i}_{k}_{j}_mexh.png', bbox_inches='tight', pad_inches=0)
    
        j=j+1
  j = 0
  i=i+150

# %%
# Clase 4

i = 18000
j= 0

for k in range(18300,24001,150):  
  while(j<8):

        data1=df.iloc[:,j]
        data2=data1[i:k]  
        cwtmatr, freqs = pywt.cwt(data2, np.arange(1,100,1), 'mexh')
        plt.imshow(cwtmatr, cmap='inferno', aspect='auto', extent=[0, 1.5, 100, 0])
        plt.gca().invert_yaxis()
        plt.axis('off')
        plt.savefig(rf'D:\TESIS\6000 datos\Datos\P10\Mexican_Hat_img\clase_4\{i}_{k}_{j}_mexh.png', bbox_inches='tight', pad_inches=0)
    
        j=j+1
  j = 0
  i=i+150

# %%
# Clase 5

i = 24000
j= 0

for k in range(24300,30001,150):  
  while(j<8):

        data1=df.iloc[:,j]
        data2=data1[i:k]  
        cwtmatr, freqs = pywt.cwt(data2, np.arange(1,100,1), 'mexh')
        plt.imshow(cwtmatr, cmap='inferno', aspect='auto', extent=[0, 1.5, 100, 0])
        plt.gca().invert_yaxis()
        plt.axis('off')
        plt.savefig(rf'D:\TESIS\6000 datos\Datos\P10\Mexican_Hat_img\clase_5\{i}_{k}_{j}_mexh.png', bbox_inches='tight', pad_inches=0)
    
        j=j+1
  j = 0
  i=i+150

# %%
signal = data1[200:225]

# %%
# Clase 6

i = 30000
j= 0

for k in range(30300,36001,150):  
  while(j<8):

        data1=df.iloc[:,j]
        data2=data1[i:k]  
        cwtmatr, freqs = pywt.cwt(data2, np.arange(1,100,1), 'mexh')
        plt.imshow(cwtmatr, cmap='inferno', aspect='auto', extent=[0, 1.5, 100, 0])
        plt.gca().invert_yaxis()
        plt.axis('off')
        plt.savefig(rf'D:\TESIS\6000 datos\Datos\P10\Mexican_Hat_img\clase_6\{i}_{k}_{j}_mexh.png', bbox_inches='tight', pad_inches=0)
    
        j=j+1
  j = 0
  i=i+150

# %% [markdown]
# # **Test**

# %%
# Set sampling frequency and time vector
fs = 100
t = 300

scale = (1 * 300) / (2 * 1.25 * 1)

# %%
scale
# Out:
# 120.0

# %%
# Compute continuous wavelet transform
cwtmatr, freqs = pywt.cwt(signal, np.arange(1,15,1), 'mexh')

# %%
# Plot CWT coefficients
plt.imshow(cwtmatr, cmap='viridis', aspect='auto', extent=[0, 1.5, 100, 0])
plt.gca().invert_yaxis()
plt.axis('off')
plt.savefig(r'D:\TESIS\6000 datos\prueba.png', bbox_inches='tight', pad_inches=0)

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(signal, color='tab:blue')
plt.show()

# %%
# !pip3 install --upgrade pywt
# Out:
# ERROR: Could not find a version that satisfies the requirement pywt (from versions: none)
# ERROR: No matching distribution found for pywt

# %%
import numpy as np
import matplotlib.pyplot as plt
import pywt


# Set the parameters for the CWT
wavelet = 'db4'  # Daubechies 4 mother wavelet
scales = np.arange(1, 128)
sampling_frequency = 200  # Hz

# Perform the CWT
coefficients, frequencies = pywt.cwt(data2, scales, wavelet, sampling_period=1/sampling_frequency)

# Plot the CWT image
plt.imshow(np.abs(coefficients), extent=[0, len(data2), np.min(frequencies), np.max(frequencies)], cmap='viridis', aspect='auto')
plt.xlabel('Time (samples)')
plt.ylabel('Frequency (Hz)')
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-90288b9eba37> in <module>
#      10
#      11 # Perform the CWT
# ---> 12 coefficients, frequencies = pywt.cwt(data2, scales, wavelet, sampling_period=1/sampling_frequency)
#      13
#      14 # Plot the CWT image
#
# c:\Users\hpalm\anaconda3\envs\tfradeon\lib\site-packages\pywt\_cwt.py in cwt(data, scales, wavelet, sampling_period, method, axis)
#     121         raise ValueError("axis must be a scalar.")
#     122
# --> 123     dt_out = dt_cplx if wavelet.complex_cwt else dt
#     124     out = np.empty((np.size(scales),) + data.shape, dtype=dt_out)
#     125     precision = 10
#
# AttributeError: 'pywt._extensions._pywt.Wavelet' object has no attribute 'complex_cwt'
